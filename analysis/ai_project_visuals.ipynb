# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from scipy.stats import kstest

# %%
mctsAgentData = [530.0, -147.0, -492.0, -518.0, -375.0, -460.0, 249.0, 750.0, -429.0, -423.0, 81.0, 78.0, -491.0, -462.0, 200.0, -492.0, 321.0, -473.0, -419.0, -224.0, -245.0, -628.0, -482.0, -359.0, -137.0, 101.0, -90.0, -471.0, -6.0, -478.0, -437.0, 21.0, -266.0, -264.0, -515.0, -212.0, 796.0, 81.0, 226.0, -482.0, -491.0, -149.0, -792.0, 326.0, 1212.0, -491.0, 104.0, 405.0, -125.0, -454.0, -49.0, -368.0, -122.0, -524.0, -455.0, -344.0, 44.0, -273.0, -93.0, 138.0, 26.0, 534.0, 432.0, -227.0, -27.0,-444.0, 712.0, 7.0, 768.0, 290.0, 467.0, -542.0, 926.0, -17.0, 880.0, 497.0, 265.0, 643.0, 296.0, 563.0, 874.0, 439.0, 313.0, -184.0, 718.0, -71.0, 1034.0, -305.0, -82.0, 898.0, 882.0, -386.0, 487.0, 782.0, 426.0] 
betterMctsData = [542.0, 1501.0, 516.0, 560.0, -339.0, -395.0, -478.0, 828.0, -405.0, -492.0, -440.0, 1472.0, -261.0, -425.0, -487.0, -458.0, 1722.0, -482.0, 293.0, 234.0, -48.0, -377.0, -427.0, 76.0, 1098.0, 477.0, 1275.0, 776.0, 1074.0, -455.0, -371.0, 1087.0, 747.0, 1430.0, -86.0, 962.0, 493.0, 570.0, 1273.0, -406.0, 51.0, 751.0, -294.0, 1090.0, 1111.0, 1865.0, 654.0, 1060.0, 1502.0, 1190.0, 1306.0, 180.0, 1603.0, 477.0, 14.0, 576.0, 3000.0, 295.0, 1798.0, 1398.0, 2381.0, 989.0, -4.0, 1170.0, 813.0,-13.0, 1046.0, 289.0, 552.0, 547.0, 459.0, 316.0, 1525.0, 581.0, 2159.0, 709.0, 829.0, 773.0, 1291.0, 1807.0, 978.0, 1041.0, 2277.0, 1793.0, 867.0, 1973.0, 41.0, 707.0, 1320.0, 1573.0, 870.0, 379.0, 1119.0, 1378.0, 1501.0] 
alphaBetaData = [482.0, -220.0, 516.0, 516.0, -188.0, -464.0, 1619.0, 0.0, 661.0, -492.0, -513.0, 1729.0, -491.0, -457.0, -473.0, -439.0, 415.0, -461.0, -109.0, -25814.0, -459.0, -45017.0, -429.0, -457.0, -604.0, -650.0, -436.0, 581.0, 1253.0, -411.0, 782.0, 851.0, -332.0, -187.0, -617.0, -41006.0, -22.0, -44651.0, -359.0, -526.0, -313.0, -716.0, -4139.0, -562.0, -2916.0, -491.0, -397.0, -414.0, 1097.0, -40135.0, -666.0, -52680.0, 284.0, -588.0, -79539.0, -407.0, 846.0, -284.0, -39.0, -742.0, 816.0, -121.0, -305.0, -547.0, -1374.0,-36.0, 180.0, 108.0, -749.0, 131.0, 378.0, -460.0, 405.0, 99.0, 135.0, 207.0, 233.0, 108.0, 904.0, 305.0, -1510.0, 79.0, 81.0, -487.0, 271.0, 72.0, 126.0, 308.0, 295.0, 125.0, 162.0, 579.0, 36.0, 33.0, 252.0] 
expectiMaxData = [520.0, -426.0, 516.0, 508.0, -137.0, -583.0, -220.0, 0.0, 651.0, -576.0, -438.0, 1800.0, -1617.0, -499.0, -451.0, -490.0, 778.0, -438.0, 66.0, 1582.0, 766.0, -46483.0, 609.0, -908.0, 332.0, -70.0, -333.0, 773.0, 239.0, -443.0, -94.0, -28346.0, -368.0, 1349.0, -503.0, -40200.0, -448.0, -46285.0, -778.0, -421.0, -403.0, -1328.0, -4147.0, -858.0, 112.0, -502.0, 287.0, -347.0, -1084.0, -37773.0, 504.0, -56854.0, 359.0, 107.0, -82842.0, -3742.0, -653.0, -924.0, 1258.0, -297.0, -6061.0, 985.0, -51.0, -343.0, -857.0,-109.0, -394.0, 36.0, -775.0, 137.0, 207.0, 1256.0, 117.0, 63.0, 27.0, 9.0, 54.0, 63.0, 534.0, 153.0, -736.0, 594.0, 36.0, -531.0, 291.0, 18.0, 117.0, 138.0, -20.0, 131.0, 9.0, 650.0, 9.0, 112.0, 126.0]

# %%
# Function to remove outliers using IQR method
def remove_outliers(data):
    q1 = np.percentile(data, 25)
    q3 = np.percentile(data, 75)
    iqr = q3 - q1
    lower_bound = q1 - 4 * iqr
    upper_bound = q3 + 4 * iqr
    print(lower_bound, upper_bound)
    return [x for x in data if x >= lower_bound and x <= upper_bound]

# %%
mctsAgentData1 =  remove_outliers(mctsAgentData)
betterMctsData1 =  remove_outliers(betterMctsData)
alphaBetaData1 = remove_outliers(alphaBetaData)
expectiMaxData1 =  remove_outliers(expectiMaxData)
print(len(mctsAgentData1), len(betterMctsData1), len(alphaBetaData1), len(expectiMaxData1))
# Out:
# -3567.0 3511.5
# -4778.5 6116.0
# -3427.5 3178.5
# -3305.0 2968.0
# 95 95 87 85

# %%
mctsAgentMean =  np.mean(mctsAgentData1)
betterMctsMean  =  np.mean(betterMctsData1)
alphaBetaMean  = np.mean(alphaBetaData1)
expectiMaxMean =  np.mean(expectiMaxData1)
print(mctsAgentMean, betterMctsMean, alphaBetaMean, expectiMaxMean)
# Out:
# 24.526315789473685 714.0736842105263 -67.35632183908046 -17.235294117647058

# %%
# Labels for the bars
labels = ['MCTS Agent', 'Better MCTS Agent', 'Alpha-Beta Agent', 'ExpectiMax Agent']

# Heights of the bars
average_scores = [mctsAgentMean, betterMctsMean, alphaBetaMean, expectiMaxMean]

# Plotting the bars
plt.bar(labels, average_scores, color=['blue', 'orange', 'green', 'red'])
plt.grid(True)

# Adding labels and title
plt.xlabel('Agent Type')
plt.xticks(rotation=45, ha='right')
plt.ylabel('Average Scores')
plt.title('Overall Average Scores Comparison (Outliers Removed)')
plt.tight_layout()

# %%
mctsSmall = mctsAgentData[0:35]
mctsMedium = mctsAgentData[35:65]
mctsLarge = mctsAgentData[65:]

bettermctsSmall = betterMctsData[0:35]
bettermctsMedium = betterMctsData[35:65]
bettermctsLarge = betterMctsData[65:]

abSmall =  alphaBetaData[0:35]
abMedium = alphaBetaData[35:65]
abLarge = alphaBetaData[65:]

emSmall = expectiMaxData[:35]
emMedium = expectiMaxData[35:65]
emLarge = expectiMaxData[65:]

# %%
# Sample data arrays
labels = ['Small', 'Medium', 'Large']
data1 = [np.mean(remove_outliers(mctsSmall)), np.mean(remove_outliers(mctsMedium)), np.mean(remove_outliers(mctsLarge))]
data2 = [np.mean(remove_outliers(bettermctsSmall)), np.mean(remove_outliers(bettermctsMedium)), np.mean(remove_outliers(bettermctsLarge))]
data3 = [np.mean(remove_outliers(abSmall)), np.mean(remove_outliers(abMedium)), np.mean(remove_outliers(abLarge))]
data4 = [np.mean(remove_outliers(emSmall)), np.mean(remove_outliers(emMedium)), np.mean(remove_outliers(emLarge))]

# Width of each bar
bar_width = 0.15

# Positions for the bars
x = np.arange(len(labels))

# Plotting the bars for each data array for each label
plt.bar(x - 1.5 * bar_width, data1, width=bar_width, label='MCTS Agent', color='blue')
plt.bar(x - 0.5 * bar_width, data2, width=bar_width, label='Better MCTS Agent', color='orange')
plt.bar(x + 0.5 * bar_width, data3, width=bar_width, label='Alpha-Beta Agent', color='green')
plt.bar(x + 1.5 * bar_width, data4, width=bar_width, label='ExpectiMax Agent', color='red')
plt.grid(True)

# Adding labels and title
plt.xlabel('Layout Sizes')
plt.ylabel('Average Scores')
plt.title('Average Score Comparison in Different Layouts')
plt.xticks(x, labels)
plt.legend()

# Displaying the plot
plt.tight_layout()
plt.show()
# Out:
# -1278.0 778.5
# -2328.0 2095.5
# -3077.0 3821.5
# -5283.0 5670.0
# -2786.0 4564.75
# -3084.75 5114.25
# -4338.5 4369.0
# -4923.0 3417.75
# -696.25 1036.25
# -4424.5 4472.0
# -15242.5 11991.5
# -506.0 652.75

# %%
mctsTest = [530.0, 531.0, 551.0, 494.0, 540.0, 527.0, 517.0, 497.0, 544.0, 504.0, -499.0, -477.0, 521.0, 493.0, 533.0, 410.0, 546.0, 498.0, -570.0, -505.0, 553.0, 527.0, 521.0, 532.0, -508.0, 487.0, -491.0, -544.0, 491.0, 521.0]

betterMctsTest = [538.0, 534.0, 544.0, 554.0, 550.0, 554.0, 550.0, 536.0, 518.0, 524.0, 538.0, 554.0, 540.0, 540.0, 554.0, 558.0, 528.0, 540.0, 550.0, 542.0, 546.0, 544.0, 538.0, 532.0, 544.0, 512.0, 536.0, 558.0, 548.0, 532.0]

mctsSmall = [-431.0, -302.0, -378.0, -114.0, -238.0, -164.0, -241.0, 296.0, -351.0, -300.0, -366.0, -213.0, -389.0, 95.0, -168.0, -108.0, -301.0, -361.0, 96.0, -402.0, -424.0, -143.0, 53.0, -81.0, -353.0, -370.0, -133.0, -172.0, -352.0, -365.0]

betterMctsSmall = [440.0, 262.0, 1241.0, 455.0, -425.0, 125.0, -138.0, 1507.0, 232.0, 1526.0, 1031.0, 1125.0, 75.0, 918.0, 1105.0, 1262.0, 297.0, -316.0, 1492.0, -146.0, 1268.0, 1632.0, -308.0, -282.0, 104.0, 1530.0, -239.0, -264.0, 90.0, -257.0] 

winPercent1, winPercent2, winPercent3, winPercent4 = 0,0,0,0

for i in range(len(mctsTest)):
    if mctsTest[i]>=410:
        winPercent1 +=1
    if betterMctsTest[i]>=410:
        winPercent2 +=1
    if mctsSmall[i]>=1000:
        winPercent3 +=1
    if betterMctsSmall[i]>=1000:
        winPercent4 +=1

winPercent1 /= len(mctsTest)
winPercent2 /= len(betterMctsTest)
winPercent3 /= len(mctsSmall)
winPercent4 /= len(betterMctsSmall)

# data11 = ['Win' if x >= 410 else 'Lose' for x in data1]

# data21 = ['Win' if x >= 410 else 'Lose' for x in data2]

print(winPercent1 * 100, winPercent2 * 100, winPercent3 * 100, winPercent4 * 100)

# Sample data arrays
labels = ['testClassic', 'smallClassic']

# Width of each bar
bar_width = 0.03

# Positions for the bars
x = np.arange(len(labels))

# Plotting the bars for each data array for each label
plt.bar(x - 1.5 * bar_width, [winPercent1 * 100, winPercent3 * 100], width=bar_width, label='MCTS Agent w/ 10000 iterations', color='blue')
plt.bar(x - 0.5 * bar_width, [winPercent2 * 100, winPercent4 * 100], width=bar_width, label='Better MCTS Agent w/ 500 iterations', color='orange')

plt.grid(True)
# Adding labels and title
plt.xlabel('Layout Sizes')
plt.ylabel('Win Percentage')
plt.title('Win Percentage Comparison w/ Different Iteration Values')
plt.xticks(x, labels)
plt.legend()

# Displaying the plot
plt.figure(figsize=(1, 6))  # Width and height are specified in inches
plt.tight_layout()
# Add gridlines
plt.show()

# # Plotting box plots
# plt.figure(figsize=(10, 5))
# plt.subplot(1, 2, 1)
# sns.boxplot(data=[data1, data2])
# plt.xticks([0, 1], ['Algorithm 1', 'Algorithm 2'])
# plt.title('Box Plot of Scores')

# # Plotting histograms
# plt.subplot(1, 2, 2)
# sns.histplot(data1, bins=100, label='Algorithm 1', color='blue', alpha=0.5)
# sns.histplot(data2, bins=10, label='Algorithm 2', color='orange', alpha=0.5)
# plt.xlabel('Scores')
# plt.ylabel('Frequency')
# plt.title('Histogram of Scores')
# plt.legend()

# # Displaying the plots
# plt.tight_layout()
# plt.show()

# # Combine the data arrays and create a labels array
# data = {'Algorithm 1': data1, 'Algorithm 2': data2}

# # Create a DataFrame from the data dictionary
# import pandas as pd
# df = pd.DataFrame(data)

# # Plotting the violin plot
# plt.figure(figsize=(8, 6))
# sns.violinplot(data=df, inner="point", linewidth=1)

# # Adding labels and title
# plt.xlabel('Algorithms')
# plt.ylabel('Scores')
# plt.title('Violin Plot of Scores for Two Algorithms')

# Displaying the plot
# Out:
# 76.66666666666667 100.0 0.0 36.666666666666664

# %%
def normalityTest(data):
    # Perform Shapiro-Wilk test
    statistic, p_value = kstest(data, 'norm')

    # Print the test statistic and p-value
    print("Shapiro-Wilk Test:")
    print("Statistic:", statistic)
    print("p-value:", p_value)

    # Interpret the result
    alpha = 0.05
    if p_value > alpha:
        print("Sample looks Gaussian (fail to reject H0)")
    else:
        print("Sample does not look Gaussian (reject H0)")

# %%
def runTTest(data1, data2):
#     print("Environment: ", environments)
#     print("Scores: ", scores1, scores2, scores3)

#     print("Agent 1 normality test")
#     normalityTest(scores1)
#     print("Agent 2 normality test")
#     normalityTest(scores2)
#     print("Agent 3 normality test")
#     normalityTest(scores3)

#     normalityTest(data1)
#     normalityTest(data2)

    t_statistic1, p_value1 = stats.ttest_rel(data1, data2)
#     t_statistic2, p_value2 = stats.ttest_rel(scores2, scores3)

    # Define significance level (alpha)
    alphatTest = 0.05

    # Determine whether to reject or accept the null hypothesis
    print("------t-Test Agent 1 vs Agent 3------")
    if p_value1 < alphatTest:
        print("Reject the null hypothesis: There is a significant difference between the means")
    else:
        print("Accept the null hypothesis: There is no significant difference between the means")

#     print("------t-Test Agent 2 vs Agent 3------")
#     if p_value2 < alphatTest:
#         print("Reject the null hypothesis: There is a significant difference between the means")
#     else:
#         print("Accept the null hypothesis: There is no significant difference between the means")

    # Print t-statistic and p-value
    print("t-statistic:", t_statistic1)
    print("p-value:", p_value1)

# %%
runTTest(mctsAgentData, betterMctsData)
runTTest(mctsAgentData, alphaBetaData)
runTTest(betterMctsData, alphaBetaData)
runTTest(betterMctsData, expectiMaxData)
runTTest(mctsAgentData, expectiMaxData)
# Out:
# ------t-Test Agent 1 vs Agent 3------
# Reject the null hypothesis: There is a significant difference between the means
# t-statistic: -9.251074161304025
# p-value: 7.193472016046262e-15
# ------t-Test Agent 1 vs Agent 3------
# Reject the null hypothesis: There is a significant difference between the means
# t-statistic: 2.708570296552895
# p-value: 0.008029418896020282
# ------t-Test Agent 1 vs Agent 3------
# Reject the null hypothesis: There is a significant difference between the means
# t-statistic: 3.227143038005039
# p-value: 0.0017215988570711883
# ------t-Test Agent 1 vs Agent 3------
# Reject the null hypothesis: There is a significant difference between the means
# t-statistic: 3.232648923969552
# p-value: 0.0016920494471576375
# ------t-Test Agent 1 vs Agent 3------
# Reject the null hypothesis: There is a significant difference between the means
# t-statistic: 2.7362701471362856
# p-value: 0.007429962245105136

# %%
# sns_kde1 = sns.kdeplot(mctsAgentData1, label='Data 1', fill=True)
# sns_kde2 = sns.kdeplot(betterMctsData1, label='Data 2', fill=True)
# sns_kde3 = sns.kdeplot(alphaBetaData1, label='Data 3', fill=True)
# sns_kde4 = sns.kdeplot(expectiMaxData1, label='Data 4', fill=True)

# Plot distribution curves
sns.kdeplot(mctsAgentData1, label='MCTS Agent', fill=True)
sns.kdeplot(betterMctsData1, label='Better MCTS Agent', fill=True)
sns.kdeplot(alphaBetaData1, label='Alpha-Beta Agent', fill=True)
sns.kdeplot(expectiMaxData1, label='Expectimax Agent', fill=True)

colors = []
for coll in plt.gca().collections:
    colors.append(coll.get_facecolor()[0]) 

print(colors)

# Calculate and plot mean for each dataset
means = [np.mean(mctsAgentData1), np.mean(betterMctsData1), np.mean(alphaBetaData1), np.mean(expectiMaxData1)]
for i, mean in enumerate(means):
    if colors[0][i]:
        plt.axvline(mean, color=colors[i], linestyle='--', linewidth=1, alpha=1)

plt.gca().set_yticklabels(['{:.0f}%'.format(x*10000) for x in plt.gca().get_yticks()])

# Add labels and legend
plt.xlabel('Scores')
plt.ylabel('Frequency (in %)')
plt.legend()
plt.title("Distribution Curve for Different Agents with Means")

# Show the plot
plt.show()
# Out:
# [array([0.12156863, 0.46666667, 0.70588235, 0.25      ]), array([1.        , 0.49803922, 0.05490196, 0.25      ]), array([0.17254902, 0.62745098, 0.17254902, 0.25      ]), array([0.83921569, 0.15294118, 0.15686275, 0.25      ])]
# C:\Users\loga3\AppData\Local\Temp\ipykernel_14568\2607013101.py:24: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels(['{:.0f}%'.format(x*10000) for x in plt.gca().get_yticks()])

# %%
# Sample data arrays
labels = ['Small', 'Medium']
data1 = [5.71, 6.67]
data2 = [40, 10]
data3 = [34.29, 0]
data4 = [37.14, 0]

# Width of each bar
bar_width = 0.15

# Positions for the bars
x = np.arange(len(labels))

# Plotting the bars for each data array for each label
plt.bar(x - 1.5 * bar_width, data1, width=bar_width, label='MCTS Agent', color='blue')
plt.bar(x - 0.5 * bar_width, data2, width=bar_width, label='Better MCTS Agent', color='orange')
plt.bar(x + 0.5 * bar_width, data3, width=bar_width, label='Alpha-Beta Agent', color='green')
plt.bar(x + 1.5 * bar_width, data4, width=bar_width, label='ExpectiMax Agent', color='red')
plt.grid(True)

# Adding labels and title
plt.xlabel('Layout Sizes')
plt.ylabel('Win Percentage (in %)')
plt.title('Win Percentage Comparison in Different Layouts')
plt.xticks(x, labels)
plt.legend()

# Displaying the plot
plt.tight_layout()
plt.show()
